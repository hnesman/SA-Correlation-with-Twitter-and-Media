# %%
ckey="oglAcoBXr2U41V3BRerO8SoiX"
csecret="o3MmdHBNQX5O5SV84N70IHkRCIPgOiVKNwIg1PQMznq1ZuvM8j"
atoken="848659773176385536-XOsIpQcOurrAYHE8qjnq6yq2gtJpw01"
asecret="gIazV001cMvvqtPdfJ1XyksnwSrednnNYQMb1z44PysPb"

# %%
try:
    import json
except ImportError:
    import simplejson as json

# %%
import pandas as pd
import numpy as np
import tweepy

#Tweepy
auth = tweepy.OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
api = tweepy.API(auth)

# %%
#!/usr/bin/env python
# encoding: utf-8

import tweepy #https://github.com/tweepy/tweepy
import csv

# Date as YYYY-MM-DD
def search_tweets(query,date):
	#Twitter only allows access to a users most recent 3240 tweets with this method
	
	#authorize twitter, initialize tweepy
	auth = tweepy.OAuthHandler(ckey, csecret)
	auth.set_access_token(atoken, asecret)
	api = tweepy.API(auth)
	
	#initialize a list to hold all the tweepy Tweets
	alltweets = []	
	
	#make initial request for most recent tweets (200 is the maximum allowed count)
	new_tweets = api.search(q = query,count=10, result_type = 'popular', include_entities =  True)
	
	#save most recent tweets
	alltweets.extend(new_tweets)
	
	#save the id of the oldest tweet less one
	oldest = alltweets[-1].id - 1
	
	#keep grabbing tweets until there are no tweets left to grab
	while len(new_tweets) > 0:
		print "getting tweets before %s" % (oldest)
		
		#all subsiquent requests use the max_id param to prevent duplicates
		new_tweets = api.search(q = query ,count=200,max_id=oldest, result_type = 'popular', include_entities = True)
		
		#save most recent tweets
		alltweets.extend(new_tweets)
		
		#update the id of the oldest tweet less one
		oldest = alltweets[-1].id - 1
		
		print "...%s tweets downloaded so far" % (len(alltweets))
	
	#transform the tweepy tweets into a 2D array that will populate the csv	
	outtweets = [[tweet.id_str, str(tweet.user.name.encode("utf-8")), tweet.created_at, str(tweet.text.encode("utf-8")), tweet.favorite_count, tweet.retweet_count, tweet.user.followers_count] for tweet in alltweets]
	
	#write the csv	
	with open('/users/hnesman/Downloads/DATA_Science/%s_tweets_%s.csv' % (query,date) , 'wb') as f:
		writer = csv.writer(f)
		writer.writerow(["id","Username","created_at","text","favorite_count", "retweet_count","user's followers count"])
		writer.writerows(outtweets)
	
	pass

# %%
query = '#FelizDiaDelTrabajador'
date = '2017-05-01'
search_tweets(query,date)
# Out:
# getting tweets before 859033420353110016
# ...25 tweets downloaded so far
# getting tweets before 859031531414749183
# ...40 tweets downloaded so far
# getting tweets before 858946669794164735
# ...51 tweets downloaded so far
# getting tweets before 858878895923253247
# ...51 tweets downloaded so far

# %%
# REST API

# With Tweepy
query = api.search(q = "#FelizDiaDelTrabajador", until = '2017-04-30', count = 5)

print query
# Out:
# [Status(contributors=None, truncated=False, text=u'#FelizDiaDelTrabajador haa.no es hoy?  Bueno, queta le vamos hacer.. Jaja https://t.co/T6G00ycSBw', is_quote_status=False, in_reply_to_status_id=None, id=858453115959422976, favorite_count=0, _api=<tweepy.api.API object at 0x119c93cd0>, author=User(follow_request_sent=False, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 1462140440, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/859225718244483072/QQUEOwj1_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'url': {u'urls': [{u'url': u'https://t.co/ahJ26k7NEC', u'indices': [0, 23], u'expanded_url': u'http://atilioboron.com.ar', u'display_url': u'atilioboron.com.ar'}]}, u'description': {u'urls': []}}, u'followers_count': 1011, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'1462140440', u'profile_background_color': u'C0DEED', u'listed_count': 16, u'is_translation_enabled': False, u'utc_offset': -10800, u'statuses_count': 19408, u'description': u'\xabde cada uno, seg\xfan su capacidad; a cada uno, seg\xfan sus necesidades\xbb La actitud no se negocia. @pcaarg @fjcarg #Comunista #Ch\xe1vez #AntiImperialista #Fidel #Che', u'friends_count': 2534, u'location': u'Quitilipi-Chaco', u'profile_link_color': u'1DA1F2', u'profile_image_url': u'http://pbs.twimg.com/profile_images/859225718244483072/QQUEOwj1_normal.jpg', u'following': False, u'geo_enabled': True, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1462140440/1490062101', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'screen_name': u'NuniBilla', u'lang': u'es', u'profile_background_tile': False, u'favourites_count': 7738, u'name': u'Marcelo Didier Billa', u'notifications': False, u'url': u'https://t.co/ahJ26k7NEC', u'created_at': u'Mon May 27 13:40:44 +0000 2013', u'contributors_enabled': False, u'time_zone': u'Brasilia', u'protected': False, u'default_profile': True, u'is_translator': False}, time_zone=u'Brasilia', id=1462140440, description=u'\xabde cada uno, seg\xfan su capacidad; a cada uno, seg\xfan sus necesidades\xbb La actitud no se negocia. @pcaarg @fjcarg #Comunista #Ch\xe1vez #AntiImperialista #Fidel #Che', _api=<tweepy.api.API object at 0x119c93cd0>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/859225718244483072/QQUEOwj1_normal.jpg', profile_sidebar_fill_color=u'DDEEF6', is_translator=False, geo_enabled=True, entities={u'url': {u'urls': [{u'url': u'https://t.co/ahJ26k7NEC', u'indices': [0, 23], u'expanded_url': u'http://atilioboron.com.ar', u'display_url': u'atilioboron.com.ar'}]}, u'description': {u'urls': []}}, followers_count=1011, protected=False, id_str=u'1462140440', default_profile_image=False, listed_count=16, lang=u'es', utc_offset=-10800, statuses_count=19408, profile_background_color=u'C0DEED', friends_count=2534, profile_link_color=u'1DA1F2', profile_image_url=u'http://pbs.twimg.com/profile_images/859225718244483072/QQUEOwj1_normal.jpg', notifications=False, default_profile=True, profile_background_image_url_https=u'https://abs.twimg.com/images/themes/theme1/bg.png', profile_banner_url=u'https://pbs.twimg.com/profile_banners/1462140440/1490062101', profile_background_image_url=u'http://abs.twimg.com/images/themes/theme1/bg.png', name=u'Marcelo Didier Billa', is_translation_enabled=False, profile_background_tile=False, favourites_count=7738, screen_name=u'NuniBilla', url=u'https://t.co/ahJ26k7NEC', created_at=datetime.datetime(2013, 5, 27, 13, 40, 44), contributors_enabled=False, location=u'Quitilipi-Chaco', profile_sidebar_border_color=u'C0DEED', translator ...

# %%
# public_tweets = api.user_timeline(id ='mauriciomacri' )
# for tweet in public_tweets:
#     print tweet.text

# %%
import csv
auth = tweepy.OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
api = tweepy.API(auth)


screen_name = ['hnesman']
followers = api.followers(screen_name = 'hnesman')
len(followers)
# Out:
# 3

# %%
import tweepy

ckey="oglAcoBXr2U41V3BRerO8SoiX"
csecret="o3MmdHBNQX5O5SV84N70IHkRCIPgOiVKNwIg1PQMznq1ZuvM8j"
atoken="848659773176385536-XOsIpQcOurrAYHE8qjnq6yq2gtJpw01"
asecret="gIazV001cMvvqtPdfJ1XyksnwSrednnNYQMb1z44PysPb"

auth = tweepy.OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
api = tweepy.API(auth)
alltweets = []
for tweet in tweepy.Cursor(api.search,
                           q="domingo",
                           rpp=100,
                           result_type="recent",
                           include_entities=True
                        ).items():
    print tweet.created_at, tweet.text


    
date = now()
	#make initial request for most recent tweets (200 is the maximum allowed count)
	new_tweets = api.search(created_at = date,)
	
	#save most recent tweets
	alltweets.extend(new_tweets)
	
	#save the id of the oldest tweet less one
	oldest = alltweets[-1].id - 1
	
	#keep grabbing tweets until there are no tweets left to grab
	while len(new_tweets) > 0:
		print "getting tweets before %s" % (oldest)
		
		#all subsiquent requests use the max_id param to prevent duplicates
		new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
		
		#save most recent tweets
		alltweets.extend(new_tweets)
		
		#update the id of the oldest tweet less one
		oldest = alltweets[-1].id - 1
		
		print "...%s tweets downloaded so far" % (len(alltweets))
	
	#transform the tweepy tweets into a 2D array that will populate the csv	
	outtweets = [[tweet.id_str, tweet.created_at, str(tweet.text.encode("utf-8"))] for tweet in alltweets]
	
	#write the csv	
	with open('/users/hnesman/Downloads/DATA_Science/Agentes_Twitter_Media/%s_tweets.csv' % screen_name, 'wb') as f:
		writer = csv.writer(f)
		writer.writerow(["id","created_at","text"])
		writer.writerows(outtweets)
	
	pass

# %%
# Get the User object for twitter...
# user = api.get_user('macri')
# print user.screen_name
# print user.followers_count
# followers =[]
# for friend in user.followers():
#     follow = friend.screen_name
#     followers.extend(follow)
